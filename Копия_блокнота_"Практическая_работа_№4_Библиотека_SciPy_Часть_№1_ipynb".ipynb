# %% [markdown]
# <a href="https://colab.research.google.com/github/Reape4er/computer_math/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_%E2%84%964_%D0%91%D0%B8%D0%B1%D0%BB%D0%B8%D0%BE%D1%82%D0%B5%D0%BA%D0%B0_SciPy_%D0%A7%D0%B0%D1%81%D1%82%D1%8C_%E2%84%961_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Блок №1. Базовый уровень**

# %% [markdown]
# ### **1. Константы**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Ваш код импортировать константы
from scipy.constants import  G
M = 5.972 * 10**24
R = 6371 * 10**3

def acceleration(h, h_step):
  h*=10**3
  h_step*=10**3
  k=0
  print('\tВысота (км)\tУскорение Свободного падения (м/с^2)')
  for i in range(0, h+h_step, h_step):
    g = (G * M) / ((R + i)**2)
    print(f'{k}\t{i//10**3:>11}\t\t{g:>28.5f}')
    k+=1

acceleration(1000, 100)
# Out:
# 	Высота (км)	Ускорение Свободного падения (м/с^2)
# 0	          0		                     9.81997
# 1	        100		                     9.51881
# 2	        200		                     9.23129
# 3	        300		                     8.95661
# 4	        400		                     8.69401
# 5	        500		                     8.44278
# 6	        600		                     8.20229
# 7	        700		                     7.97194
# 8	        800		                     7.75115
# 9	        900		                     7.53941
# 10	       1000		                     7.33623

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **2. Линейная алгебра**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Ваш код лин алг
import scipy
import numpy as np

coef = np.array([
    [2,3,1],
    [3,1,2],
    [1,2,3]
    ])
res = np.array([2, 7, 3]).reshape(3,1)
x = scipy.linalg.solve(coef,res)
print(x)
# Out:
# [[ 2.]
#  [-1.]
#  [ 1.]]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **3. Интегрирование**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Ваш код импортировать функцию
import scipy
from scipy.constants import pi
import numpy as np
from numpy import sqrt,exp
def f(x):
  return 1/sqrt(2*pi)*exp(-(x**2)/2)
  #return exp(((-x)**2)/2)/sqrt(2*pi)

x = np.linspace(-3,3,500)
y = f(x)
trapz_result = scipy.integrate.trapezoid(y,x)
print(f"Метод трапеций: {trapz_result}")
# Out:
# Метод трапеций: 0.9972998835680744

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **4. Методы оптимизации. Поиск корней уравнения**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Сделайте это разными способами, постройте график функции**

# %%
# Ваш код приближение сами выбираем
from numpy import cos, linspace
from scipy.optimize import root
import matplotlib.pyplot as plt
def f(x):
  return x**3+cos(x)

x = linspace(-2,2,500)
y = f(x)
plt.plot(x,y)
plt.grid(True)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for i in ['hybr','lm','broyden1','broyden2', 'anderson','linearmixing','diagbroyden','excitingmixing','krylov','df-sane']:
  x0 = -0.8
  result = root(fun=f, x0=x0, method=i )
  print(f'метод:{i:>15}\tуспех:{result.success}\tХ = {result.x}')
# Out:
# метод:           hybr	успех:True	Х = [-0.86547403]
# метод:             lm	успех:True	Х = [-0.86547403]
# метод:       broyden1	успех:True	Х = -0.8654737324917688
# метод:       broyden2	успех:True	Х = -0.8654737324917688
# метод:       anderson	успех:True	Х = -0.8654755061010075
# метод:   linearmixing	успех:False	Х = 29.929746216907393
# метод:    diagbroyden	успех:True	Х = -0.8654737324917688
# метод: excitingmixing	успех:False	Х = 264.4541546050088
# метод:         krylov	успех:True	Х = -0.865474033492336
# метод:        df-sane	успех:True	Х = -0.8654740331134374

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **5. Методы оптимизации. Поиск минимума**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Ваш код применить оптимизатор minimize
from scipy import optimize
import numpy as np
import matplotlib.pyplot as plt

def target_function(x):
    return 100*(x[1]-(x[0]**2))**2+(1-x[0])**2

x0 = np.array([1, 1])
xmin_global = optimize.minimize(target_function, x0)
print(xmin_global) # наша точка минимума
# Out:
#   message: Optimization terminated successfully.
#   success: True
#    status: 0
#       fun: 0.0
#         x: [ 1.000e+00  1.000e+00]
#       nit: 0
#       jac: [ 5.975e-06  1.490e-06]
#  hess_inv: [[1 0]
#             [0 1]]
#      nfev: 3
#      njev: 1

# %% [markdown]
# ![image.png](data:image/png;base64,...![image.png](data:image/png;base64,...))![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Блок №2. Повышенный уровень**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Ваш код
def f(x,v=1,a=1):
  return (v+x)**3-2*x**2-a*x-17
x0 = -0.8
result = root(fun=f, x0=x0,)

# %%
x = np.linspace(-5, 5, 100)
y = f(x)
plt.plot(x, y)
plt.scatter(result.x, f(result.x), color='red', label='Корень')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Графическое решение уравнения')
plt.grid(True)
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Ваш код
import scipy
import numpy as np
def f(x,v=1,a=1,y=1,M=1,u=1):
  return a*x**3-(y+M)*x**2-u*x+v
x0 = -1
result = scipy.optimize.fsolve(func=f, x0=x0,)
print(result)

x0 = 1
result1 = scipy.optimize.fsolve(func=f, x0=x0,)
print(result1)

x0 = 2
result2 = scipy.optimize.fsolve(func=f, x0=x0,)
print(result2)
# Out:
# [-0.80193774]
# [0.55495813]
# [2.2469796]

# %%
x = np.linspace(-1, 3, 50)
y = f(x)
plt.plot(x, y)
plt.scatter(result[0], f(result[0]), color='red', label='Корень1')
plt.scatter(result1[0], f(result[0]), color='black', label='Корень2')
plt.scatter(result2[0], f(result[0]), color='green', label='Корень3')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Графическое решение уравнения')
plt.grid(True)
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Ваш код оформлять коэффициенты как 1, оформить всё как функции с по умолчанию 1
import scipy
from scipy import optimize
import numpy as np
import matplotlib.pyplot as plt

def f(x, v=1, a=1, y=1, u=1, b=1):
    ans1 = 3*x[0] + x[1] + x[2] + y*x[3] - a
    ans2 = x[0] - u * x[1] + v * x[2] + 4 * x[3] - b
    ans3 = -5 * x[0] - x[2] - 7 * x[3] + 5
    ans4 = x[0] - 6 * x[1] + a * x[2] + 6 * x[3] - 3
    return [ans1, ans2, ans3, ans4]

x0 = np.array([0,0,0,0])
answer = scipy.optimize.fsolve(func=f, x0=x0)
print(answer)
# Out:
# [ 0.79487179 -0.25641026 -1.48717949  0.35897436]

# %%
print(f'x = {31/39} y = {-10/39} z = {-58/39} t = {14/39}')
# Out:
# x = 0.7948717948717948 y = -0.2564102564102564 z = -1.4871794871794872 t = 0.358974358974359

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Ваш код аналогично выше
import scipy
from scipy import optimize
import numpy as np

def f(x, v=1, a=1, y=1, u=1, b=1):
    ans1 = b * x[0] + y* x[1] + v * x[2] + x[3] - 10 * u - v
    ans2 = x[0] - 3 * u * x[1] + 2 * x[2] + 4 * a * x[3] - 9 - y
    ans3 = -5 * x[0] + v * x[1] - x[2] - 7 * x[3] + 5
    ans4 = v * x[0] - 6 * x[1] + 2 * x[2] + 6 * x[3] - u
    return [ans1, ans2, ans3, ans4]

x0 = np.array([0,0,0,0])
answer = scipy.optimize.root(fun=f, x0=x0)
print(answer.x)
# Out:
# [ 21.  -9.  17. -18.]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Ваш код
import scipy
from scipy import optimize
import numpy as np

def f1(xy):
    x, y = xy
    ans1 = 3 * np.log(x) + y * np.sin(x) + y**2 - 12
    ans2 = (x/(y**2+1)) + 2**x - 3 * y**2 - 22

    return [ans1, ans2]

def f2(xy,):
    x, y = xy
    ans1 = x**2 - y**3 + (x/(np.sin(y)+2)) + 2**x - 15
    ans2 = x * np.sin(y)**2 + np.exp(x-y) - y**2 - 17

    return [ans1, ans2]
#корни для первого графика
x0 = np.array([1, 1])
answer1 = scipy.optimize.root(fun =f1, x0=x0)
print(answer1.x)

x0 = np.array([5,5])
answer2 = scipy.optimize.root(fun =f1, x0=x0)
print(answer2.x)

#корни для второго графика
x0 = np.array([1, 1])
answer3 = scipy.optimize.root(fun =f2, x0=x0)
print(answer3.x)

x0 = np.array([0.5, -2.5])
answer4 = scipy.optimize.root(fun =f2, x0=x0)
print(answer4.x)
# Out:
# [ 5.18275965 -2.24922759]
# [5.5767428  2.96076171]
# [ 2.67543886 -0.15542155]
# [ 0.79181351 -2.28988042]

# %%
import matplotlib.pyplot as plt
# import plotly.graph_objects as go
# Создаем сетку значений x и y
x = np.linspace(0, 10, 200)
y = np.linspace(-4, 4, 200)
X, Y = np.meshgrid(x, y)
Z1, Z2 = f1([X, Y])
Z3, Z4 = f2([X, Y])
# график для f1
plt.figure()
plt.contour(X, Y, Z1, levels=[0], colors='y')
plt.contour(X, Y, Z2, levels=[0], colors='b')
plt.scatter(answer1.x[0], answer1.x[1], color='r', marker='o')
plt.scatter(answer2.x[0], answer2.x[1], color='r', marker='o')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Графическое решение системы уравнений')
plt.grid(True)
plt.show()

# fig = go.Figure(data=[
#     go.Surface(z=Z1, x=X, y=Y, colorscale='Reds', name='Z3'),
#     go.Surface(z=Z2, x=X, y=Y, colorscale='Blues',  name='Z4')
# ])
# fig.update_layout(title='3D График функции Z1z2',height = 800 )
# fig.show()
# Создаем сетку значений x и y
x = np.linspace(-0.5, 3, 200)
y = np.linspace(-3, 2, 200)
X, Y = np.meshgrid(x, y)
Z3, Z4 = f2([X, Y])
# график для f2
plt.figure()
plt.contour(X, Y, Z3, levels=[0], colors='y')
plt.contour(X, Y, Z4, levels=[0], colors='b')
plt.scatter(answer3.x[0], answer3.x[1], color='r', marker='o')
plt.scatter(answer4.x[0], answer4.x[1], color='r', marker='o')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Графическое решение системы уравнений')
plt.grid(True)
plt.show()

# fig = go.Figure(data=[
#     go.Surface(z=Z3, x=X, y=Y, colorscale='Reds', name='Z3'),
#     go.Surface(z=Z4, x=X, y=Y, colorscale='Blues',  name='Z4')
# ])
# fig.update_layout(title='3D График функции Z3z4',height=800 )
# fig.show()
# Out:
# <ipython-input-28-25fb4af85b27>:8: RuntimeWarning: divide by zero encountered in log
#   ans1 = 3 * np.log(x) + y * np.sin(x) + y**2 - 12

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Ход работы:**
#
# 1. **Определение переменных**: Определяем переменные $ \mu $, $ \nu $, и $ \gamma $, которые будут использоваться в наших уравнениях.
#
# 3. **Создание массивов данных**: Создаем два массива: `x_values` и `y_values`. `x_values` содержит значения $ x $, которые мы получаем, добавляя к $ \mu + \nu $ числа от 0 до 8 с шагом 2. `y_values` содержит соответствующие значения $ y $, которые мы также вычисляем, используя заданные значения $ \gamma $ и добавляя к нему разные числа.
#
# 4. **Подготовка матрицы коэффициентов**: Создаем матрицу `A`, которая будет использоваться для нахождения коэффициентов нашей параболы. Каждая строка матрицы `A` представляет собой значения $ 1 $, $ x $, и $ x^2 $ для каждого значения из `x_values`.
#
# 5. **Решение методом наименьших квадратов**: Функция `lstsq` принимает нашу матрицу `A` и массив `y_values`, и находит коэффициенты $ c_0 $, $ c_1 $, и $ c_2 $, которые минимизируют разницу между фактическими значениями $ y $ и значениями, предсказанными нашей параболой.
#
# 6. **Вывод результатов**: В конце мы выводим найденные коэффициенты и сумму квадратов отклонений, которая показывает, насколько хорошо наша парабола соответствует данным.

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-6c9eebb9c6cc> in <cell line: 8>()
#       6 y = np.array([γ + 0 + 2.5, γ + 0 + 4.9, γ + 0 + 8, γ + 0 + 12.1, γ + 0 + 16.9])
#       7
# ----> 8 A = np.array([[1, *x], [x, x**2]])
#       9 b = np.array(y)
#      10
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.

# %%
# Ваш код
import numpy as np
from scipy.linalg import lstsq
u = 1
v = 2
y = 3
theta = 4
x_values = np.arange(u+v,u+v+10, 2)
# print(x_values)
y_values = np.array([y+theta+2.5,y+theta+4.9,y+theta+8,y+theta+12.1,y+theta+16.9])
# print(y_values)
A = np.vstack([np.ones(len(x_values)), x_values, x_values**2]).T
# print(A )
ans = lstsq(A,y_values)
print(ans[0])
print(ans[1])

xx = np.linspace(3, 11, 101)
yy = ans[0][0] + ans[0][1]*xx +ans[0][2]*xx**2
plt.plot(x_values, y_values, 'o', label='data')
plt.plot(xx, yy)
plt.show()
# Out:
# [7.52642857 0.35       0.10357143]
# 0.005142857142857234

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def trapezoidal_rule(a, b, n, func):
    h = (b - a) / n
    integral = 0.5 * (func(a) + func(b))
    for i in range(1, n):
        integral += func(a + i * h)
    integral *= h
    return integral

def simpson_rule(a, b, n, func):
    h = (b - a) / n
    x = [a + i * h for i in range(n+1)]
    y = [func(x_i) for x_i in x]

    result = y[0] + y[n]
    for i in range(1, n, 2):
        result += 4 * y[i]
    for i in range(2, n-1, 2):
        result += 2 * y[i]

    result *= h / 3
    return result

# %%
import numpy as np
from numpy import exp, sqrt
def f(x, v=3, u=2, y=1):
  return exp(((x-v)**2)/8)
def f1(x, v=3, y=1):
  return sqrt(x**2+v+y)

v = 3
u = 1
h = 2+1.3*v - v+0.2*u-1
x = np.arange(v+0.2*u-1, 2+1.3*v, h)
y = f(x)
trapz_result = trapezoidal_rule(v+0.2*u-1, 2+1.3*v,  10, f)
print(f"Метод трапеций: {trapz_result}")

simpson_result = simpson_rule(v+0.2*u-1, 2+1.3*v,  10, f)
print(f"Метод симпсона: {simpson_result}")
print()
trapz_result1 = trapezoidal_rule(v+0.1*u, 5+1.3*v,  10, f1)
print(f"Метод трапеций: {trapz_result1}")

simpson_result1 = simpson_rule(v+0.1*u, 5+1.3*v,  10, f1)
print(f"Метод симпсона: {simpson_result1}")
# Out:
# Метод трапеций: 5.18452894485501
# Метод симпсона: 5.158749195428643
#
# Метод трапеций: 36.83077507924503
# Метод симпсона: 36.82702060456898

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Ваш код
import scipy
import numpy
from numpy import exp

v = 3
u = 1
y = 1
h = 2+1.3*v-v+0.2*u-1

x = numpy.arange(v+0.2*u-1, 2+1.3*v, h)

y = f(x)
y1 = f1(x)
trapz_result = scipy.integrate.trapezoid(y,x,)
print(f"Метод трапеций: {trapz_result}")
simpson_result = scipy.integrate.simpson(y,x)
print(f"Метод simpson: {simpson_result}")
trapz_result = scipy.integrate.trapezoid(y1,x)
print(f"Метод трапеций: {trapz_result}")
simpson_result = scipy.integrate.simpson(y1,x)
print(f"Метод simpson: {simpson_result}")
# elliprc_result = scipy.special.elliprc(y,x)
# print(f"Метод elliprc: {elliprc_result}")
# Out:
# Метод трапеций: 2.4344335988903136
# Метод simpson: 2.4344335988903136
# Метод трапеций: 8.101354831516227
# Метод simpson: 8.101354831516227

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Ваш код
import numpy as np
import matplotlib.pyplot as plt

def euler(f, x0, y0, h, n):
  y = [y0]
  for i in range(n):
    y.append(y[i] + h * f(x0 + i * h, y[i]))
  return y

def rk4(f, x0, y0, h, n):
  y = [y0]
  for i in range(n):
    k1 = h * f(x0 + i * h, y[i])
    k2 = h * f(x0 + i * h + h / 2, y[i] + k1 / 2)
    k3 = h * f(x0 + i * h + h / 2, y[i] + k2 / 2)
    k4 = h * f(x0 + i * h + h, y[i] + k3)
    y.append(y[i] + (k1 + 2 * k2 + 2 * k3 + k4) / 6)
  return y

def func(x,y):
  return (y+np.cos(x)*x**2)/x

# %%
from scipy.integrate import solve_ivp
v = 1
u = 1
theta = 1
y = 1

x0 = 3+v+0.1*u
y0 = 2+theta+0.1*y
h = 0.2
n = 10

y_euler = euler(func, x0, y0, h, n)
y_rk4 = rk4(func, x0, y0, h, n)
solution = solve_ivp(func, (x0, x0+2), y0=[y0], dense_output=True, t_eval=np.linspace(x0,x0+2, 10))
print(solution.y.flatten())
# Построение графика
x = [x0 + i * h for i in range(n + 1)]

plt.plot(x, y_euler, label="Метод Эйлера")
plt.plot(x, y_rk4, label="Метод Рунге-Кутты 4-го порядка")
plt.plot(solution.t.flatten(), solution.y.flatten(), label="scipy Метод Рунге-Кутты 4-го порядка")
plt.legend()
plt.show()
# Out:
# [3.1        2.80717718 2.67357469 2.74483222 3.05536667 3.627913
#  4.47270301 5.58288239 6.93559965 8.49246844]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x0 = 0.5*(u+theta+1)
y0 = (v+y)/2
h = 0.2
n = 10

y_euler = euler(func, x0, y0, h, n)
y_rk4 = rk4(func, x0, y0, h, n)
solution = solve_ivp(func, (x0, x0+2), y0=[y0], dense_output=True, t_eval=np.linspace(x0,x0+2, 10))
print(solution.y.flatten())
# Построение графика
x = [x0 + i * h for i in range(n + 1)]

plt.plot(x, y_euler, label="Метод Эйлера")
plt.plot(x, y_rk4, label="Метод Рунге-Кутты 4-го порядка")
plt.plot(solution.t.flatten(), solution.y.flatten(), label="scipy Метод Рунге-Кутты 4-го порядка")
plt.legend()
plt.show()
# Out:
# [ 1.          1.13288046  1.16720703  1.07640671  0.84268315  0.45723243
#  -0.07789714 -0.7483359  -1.52927629 -2.3856447 ]

# %% [markdown]
# ![image.png](data:image/png;base64,...)
